# %% [markdown]
# # How to Use Code 101

# %% [markdown]
# It is meant to be run one cell at a time aka one grey box at a time. The first cell will take awhile to run as it needs to "start the machine".

# %% [markdown]
# This Deepnote notebook is meant to give you some intuition on how to interact with code that other's in this lab have made.

# %% [markdown]
# It does not teach you how to code just how to use code.

# %% [markdown]
# That means please do not press the blue "Run notebook" button up top.

# %% [markdown]
# Thank you! and happy coding

# %%
# this is a comment, comments come after these guys: #
# they are in code but they are not code
# edit a cell i.e. a grey box by double clicking
# run a cell by clicking shift + enter
# try running this 


print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Basic Concepts

# %% [markdown]
# ### Syntax

# %% [markdown]
# Computers are dumb.

# %% [markdown]
# Contrary to popular belief.

# %% [markdown]
# Syntax refers to the punctuation and grammar of code.

# %% [markdown]
# Such as the commas, and colons, and brackets (boy do we love brackets)

# %% [markdown]
# As well as the indents, spaces, and new lines that are used in coding.

# %% [markdown]
# While using this notebook and while interacting with code in the future, you MUST pay attention to these or you are going to be very sad and frustrated. A missing parenthesis will be your down fall.

# %% [markdown]
# Similarly, as we have multiple languages, English and Spanish and so forth, so does coding.

# %% [markdown]
# We are learning to speak or read or code in Python!

# %% [markdown]
#  All of the specifics of this notebook: the syntax, the names for the types of objects, how they interact. etc are for python

# %% [markdown]
# Most of the concepts can be applied to other languages, like Matlab. Other languages will have their own nouns and verbs, but they will probably look different and the syntax and grammar of the language may be different as well.

# %% [markdown]
# ### Variables

# %%
# this is my variable x
x = 50 

# this is my variable y
y = 608309575993475397

# so rather than writing 
50 + 608309575993475397
# Out:
# 608309575993475447

# %%
# i can just write
x + y
# Out:
# 608309575993475447

# %%
# isn't that easier? "yes it is...and so is using python to analyze large data sets"
# variables help make complex objects easier to use, grab, and manipulate
# so if your variable name is longer and clunkier than the thing it represents
# you are coming up with bad variable names!

y = 10 

x + y
# Out:
# 60

# %%
# wow that changed the answer 
# because you changed what the variable y equals 
# this may seem obvious now, but when you have twenty variable names in your notebook 
# you might accidentally use one twice without noticing! 

# variable NAMES go on the left 
# you are assigning the term on the left what ever is on the right (this is not clear please explain)

# %% [markdown]
# If you leave, and the notebook goes idle,  your variables will not be stored in memory.

# %% [markdown]
# So if you get an error like: 'x is not defined' , rerun the cell that defines it i.e. x = something

# %% [markdown]
# So be ready to rerun cells if you cannot finish this in one sitting.

# %% [markdown]
# ## Basic Objects

# %% [markdown]
# Objects, the building blocks of code have TYPES.

# %% [markdown]
# You can think of the syntax as the grammar, and the objects as the words of coding.

# %% [markdown]
# Just as you can have nouns and verbs and adverbs as different TYPES of words, you can have different TYPES of objects.

# %% [markdown]
# Their TYPE influences what they can do, how they can be used, and also how they may be used with other objects

# %% [markdown]
# (remember syntax, you wouldn't say the dog blue would you?)

# %% [markdown]
# So let us go over some object TYPES that we use often in code (this is NOT a complete list).

# %% [markdown]
# ### Integers and Floats (int & float)

# %%
# these are your number boys 

# integers are whole numbers

my_integer = 1

# floats have decimals 

my_float = 1.5 

# even if they are "whole" numbers 

my_cheeky_float = 1.0

# %% [markdown]
# ### Lists (list)

# %%
# coding has objects or types of things

this_is_list = [1,2,3,4,5]
#this is an example of a list 
#lists use these [] and commas to separate elements

# %%
# a list has an order 
#can you guess what this will print out? 

print(this_is_list[1])
# Out:
# 2

# %%
#and that order starts with 0! not 1 
#an order is also called an INDEX
this_is_list[0]
# Out:
# 1

# %%
# so i have this variable x
new_list = [1,6,8,9,10]

x = 20 

# and i want it to be the 3rd item in the list 

new_list[2] = x

#i assigend list[2] as x 

new_list
# Out:
# [1, 6, 20, 9, 10]

# %%
#but if i wrote 

new_list = [1,6,8,9,10]

x = 20

x = new_list[2]

#i am assigning x to be the value of new_list[2]

x
# Out:
# 8

# %%
# please use this cell to create a variable and make it equal
# to the first element of new_list
x = 6

# is 6 the first element since python starts a 0?

# %%
# please change the 3rd element of new_list to 50 
# you must use a variable 
new_value = 50
new_list[2] = new_value

# %% [markdown]
# ### Strings (str)

# %%
# strings are sequences of characters (letters and spaces and other things) 
#so when you want to interact with text, this is how you would do it
# they are denoted by quotes: ' ' these

variable_name = 'hello'
print(variable_name, 'and another string')

#if there are no '' that is not a string
# Out:
# hello and another string

# %%
#fix this cell so that it prints: this is not a string 
#using TWO different methods:one with a variable name one without

#use this first method here

print (variable_name, 'this is not a string')
# Out:
# hello this is not a string

# %%
#put the second method down here 
name = ("this is not a string")
print('this is not a string')
# Out:
# this is not a string

# %% [markdown]
# ### Arrays (arr)

# %%
import numpy as np
#specifically numpy arrays are fancy lists
#but they are not lists! 
not_an_array = [1, 4, 5, 6, 7]

#oh no i have this beatuiful list! but i want a numpy array 
# np is shorthand for numpy

an_array = np.array(not_an_array)

# aha now i turned a list into a numpy array

# %%
# why would i do this?
# because numpy (which you can think of as a toolbox)

# in order to use these tools, you gotta specificy np such as 

max_item = np.max(an_array)
max_item
# Out:
# 7

# %%
# okay i lied a little bit, sometimes np tools work on lists

max_item = np.max(not_an_array)
max_item
# Out:
# 7

# %%
# so numpy has all these wonderful tools! but they work best on numpy arrays 
# its like numpy is a set of super cool hammers
# but if you have a bunch of lists, you are basically working with a bunch of screws

# you can try hammering in your screws, and it may work! 
# it also might not

# long story short: if you have a type and need a different type:
# google how do i change x into y

# %% [markdown]
# ### Dictionaries (dict)

# %%
#dictionaries are composed of two things
#keys and values
#they use {} and : to separate keys and values
#a key and a value pair make up an item
my_first_dict = {"key1": "value1"}


# this is a dictionary
# both keys and values are strings (str)
# like in a real dictionary, the keys are words and the values are their definitions
gre_vocab = {'inchoate': 'just begun and so not fully formed or developed; rudimentary',
            'denouement': 'the final part of a play, movie, or narrative in which the strands of the plot are drawn together and matters are explained or resolved',
            'erudite':  'having or showing great knowledge'
            }

# %%
#how to see the keys
gre_vocab.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 2
#       1 #how to see the keys
# ----> 2 gre_vocab.keys()
#
# NameError: name 'gre_vocab' is not defined

# %%
#how to see the values
gre_vocab.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 #how to see the values
# ----> 2 gre_vocab.values()
#
# NameError: name 'gre_vocab' is not defined

# %%
#how to see the items 
gre_vocab.items()
# Out:
# dict_items([('inchoate', 'just begun and so not fully formed or developed; rudimentary'), ('denouement', 'the final part of a play, movie, or narrative in which the strands of the plot are drawn together and matters are explained or resolved'), ('erudite', 'having or showing great knowledge')])

# %%
# how to see the value of a given key
# like in a dictionary (at least the printed ones, not the online ones)
# you find definitions by looking up words 

gre_vocab['inchoate'] 

# you don't find words in the dictionary by looking up definitions
# your keys help you find values! values may be clunky, keys should be easier to type or access
# Out:
# 'just begun and so not fully formed or developed; rudimentary'

# %%
#how to create a new key + value pair
gre_vocab['pi'] = 3.14 

#the values do not have to be of the same type
#although the value of pi is definitely not a gre vocab word

# %%
# use this cell to create your own dictionary 
# make the keys strings of the names of your family members
# make the values lists of 3 numbers representin their birthdays 
# i.e. the first element should be the day
# the second element the month
# and the third element should be the year

family_birthdays = {'Alyssa_Newman' : "070401"}, {'Trina_Howell' : '061461'}
# remember what brackets lists need!

# %%
# use this cell to see your favorite family members birthday 
# using your dictionary and their name
family_birthdays = 'Alyssa_Newman'

# %%
# surpirse! im joining the family! 
# use this cell to add me to your family dictionary! 
# my name is Meghan and my birthday is Sept 28, 1996

# %% [markdown]
# ### DataFrames (df)

# %%
# dataframes, specifically pandas dataframes 
# are like fancy excel sheets in code form

import pandas as pd

# pandas like numpy is a toolbox, used on pandas dataframes
# like numpy it has a shorthand: pd 

ppl_dict = {'Pierre': {'Town': 'Great Barrington', 'Age': 51, 'Height': 5.9},
            'Ali': {'Town': 'Avon', 'Age': 51, 'Height': 5.6},
            'Joanne': {'Town': 'Naples','Age':75, 'Height': 5.6}}


ppl_df = pd.DataFrame.from_dict(ppl_dict,orient='index')
ppl_df
# Out:
#                     Town  Age  Height
# Pierre  Great Barrington   51     5.9
# Ali                 Avon   51     5.6
# Joanne            Naples   75     5.6

# %%
# they are good for visualization 
# they are great for reading excel sheets or saving info as an excel sheet
# and pandas has some very elegant tools to use on their dataframes!

#let's say i wanted a new dataframe of only those people aged 51

same_age = ppl_df[ppl_df['Age']== 51]
same_age
# Out:
#                     Town  Age  Height
# Pierre  Great Barrington   51     5.9
# Ali                 Avon   51     5.6

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Calling Functions

# %%
#how to use a function

#my function takes in two numbers and prints out their sum
def how_to_add(x, y):
    output = x + y
    print(output)
# Out:
# 5

# %%
# how to call my function
how_to_add(2,3)
# Out:
# 5

# %%
#edit this cell please call my_function such that it prints 11

how_to_add()
# Out:
# 11

# %% [markdown]
# ### DocStrings

# %%
def how_old(family_birthdays, name):
    """
    This is called a doc string. It will tell you what a function does.
    This function will tell you how old you family members are. 

    Args(2): 
        my_input1: dict, dictionary of family members where
            keys: str, names
            values, list, birthdays such that [day,month,year]
        my_input2: str, family member's name whose age you forgot

    Returns (1):
        output: int, the age of that family member
       
    """

    #Args(no.) = arguments, the inputs required by the function, no. of arguments needed
        #name_of_input: type, description of the argument
    
    #Returns(no.) = returns, the output of the function, no. of outputs
        #name_of_return: type, description of the return 

    [day,month,year] = family_dict[name]
    if month < 9:
        age = 2023 - year
    if month >= 9:
        age = 2023 - year - 1
    return age

# %%
# i can use my function like this: 
# i put my values directly into the function

my_age = how_old(family_birthdays, 'Meghan')

# %%
# or i can create variables for them 

me = 'Meghan'

my_age_again = how_old(family_birthdays, me)

# %%
# now you try to use random_function
# please add the missing arguments into the parenthesis after random_function(...)

age = how_old()

# %%
# now try it again but using varaibles for your arguments 

your_fave_fam_member = 

age_again = how_old()

# %%
# now the fun thing about doc_strings
# unlike comments
# is their ability to appear places and cells that they weren't written in...

# %%
# now here is an empty cell
# call how_old again...

another_fam_age =

# %%
# this means when calling a function, type slowly
# or at least pause after the first parenthesis 

# and remember the first line describes the first argument
# once you type a comma, 
# type and description of the second argument will be the first line of the floating doc string

# this is special to deepnote! i think it's the bee's knees

# %%
def hidden_docstring(your_name):
    """
    this is a doc string 
    it will tell you what a function does
    what it needs: Args (arguments) and what TYPE they must be
    what it spits out: Returns and what TYPE they are 

    Args(1):
        my_argument: str, your name
    
    Returns:
        a printed statement 
    """
    print('good job,', your_name, 'for reading instructions')

# %%
# mua ha ha i have hidden my code above (do not show it)
# however, i do need you to run it
# so click the above cell and press shift + enter

# do you see the green check?
# okay good, you may continue

# %%
# in this cell try using the function: hidden_docstring 
# like how you used how_old above, hint start typing hidden_docstring
# now add a parenthesis

# %%
# hint: you should not be typing your_name, that is the variable name 
# it is a place holder for what i am asking for
# please read the description of what my_argument SHOULD be, and input that

# %%
def can_you_read(a_string, a_list, an_integer):
    """
    This function is to test your reading skills.

    Args (3):
        a_string: str, a random string
        a_list: lst, a random list
        an_integer: int, (ooh a new type!) a random interger please
    
    Returns (1):
        your_grade: flt, your grade on this mini assignment. 
                    if it is not a 100 you should try again.
    """

    your_grade = 0
    if type(a_string) is str: 
        your_grade = your_grade + 33.33
    if type(a_list) is list:
        your_grade = your_grade + 33.33
    if type(an_integer) is int:
        your_grade = your_grade + 33.34
    return your_grade

# %%
#now try using my other newest function: can_you_read
# Out:
# 99.99

# %% [markdown]
# But seriously if you do not have the time to read the doc strings, do not bother trying to use my code.

# %% [markdown]
# ### Return vs Print

# %%
# deepnote and jupyter lab are a bit weird
# they print out the last object (any line without an =)

x = 10
x
# Out:
# 10

# %%
# for example this will not print 
y = x + 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 x = x + 5
#
# NameError: name 'x' is not defined

# %%
# because of the way deepnote works, this will print out my age

how_old(family_birthdays, me)

#but it will not save it

# %%
# because of how deepnote works, this will not print out my age

how_old(family_birthdays, me)

# because of this line of code below

x = 10

# %%
# so remember printing something out does not save it
# nor does it make it easy to access later 

#but no worries, i saved my age quite a few cells ago

print('Meghan is' my_age, 'years old')

# %% [markdown]
# ## Classes

# %%
# classes are fancy objects 
# classes have attributes and methods

# attributes are unique qualities to that class
# methods are unique functions for that class

# in this example i am creating a pet
# pets have names (attribute) 
# pets can speak (method)

class Pet():
    """
    A class for cute lil pets

    Atrributes: 
        name: str, the name of your pet
        spayed: Boolean, default=False, True if your pet is spayed
                False if it is not
    
    Methods:
        get_name(): returns name of pet
        speak(text): prints {text} as if your pet said it
        is_spayed(): returns True statement if pet is spayed 
                     and False if it is not
        get_spayed(): spays your pet i.e. changes self.spayed to True
        has_babies(): your pet will have a baby and return a pet instance

    """

    def __init__(self, name):
        self.name = name
        self.spayed = False

    def get_name(self):
        """
        Returns name of pet

        Args():
            None
        Returns:
            self.name: str, name of pet
        """
        return self.name

    def speak(self, text):
        """
        prints pet_name says text

        Args(1):
            text: str, text you want your pet to say

        Returns:
            none
        """
        print(self.name, 'says', text)    
    
    def is_spayed(self):
        """
        Returns whether or not your pet is spayed.
        True for spayed, false for not spayed.

        Args():
            None
        
        Returns:
            self.spayed: Boolean, spayed status of your pet
        """
        return self.spayed

    def get_spayed(self):
        """
        Spays your pet if it is not already spayed.
        Will change self.spayed from False to True.

        Args():
            none
        Returns:
            none
        """
        self.spayed = True

    def has_babies(self):
        """
        Your pet will have a baby if it is not spayed. 
        Creates a new instance of a pet with the name baby. 

        Args():
            None
        Returns:
            baby: class Pet() instance 
        """

        if not self.spayed:
            return Pet('baby')
        else:
            raise ValueError('Pet is spayed. cannot have babies') 
            return None

# %% [markdown]
# ### Creating an instance

# %%
# this is how i would create a pet
# a class object is called an instance 
# again doc strings will appear and tell you what you need to make an instance of that class

megs_pet = Pet('Wolfie')

# so meg's pet is an instance of a pet

# %%
# using class functions
# a function that needs no inputs or arguments STILL NEED parenthesis 

megs_pet_name = megs_pet.get_name()

# %%
# another way of accessing attributes is by calling them directly
# these do not need parenthesis because it is not a function 

megs_pet.name
# Out:
# 'Wolfie'

# %%
# another example

megs_pet.is_spayed()
# Out:
# False

# %%
# or

megs_pet.spayed
# Out:
# False

# %%
# this class function requires an argument
# this function does not change any attributes of my instance

megs_pet.speak('bark')
# Out:
# Wolfie says bark

# %%
# some functions will alter my instance
# and not return anything 

megs_pet.get_spayed()

# in this case it spays my pet

megs_pet.is_spayed()
# Out:
# True

# %%
# i do not need to save the output of the function get_spayed 
# i.e. spayed = megs_pet.get_spayed()
# because 
# 1. it returns nothing
# 2. it changes my class instance
# basically saving it within my instance

# %%
# however, some class functions ONLY return things 

scar = Pet('Scar')

kitten = scar.has_babies()

#has_babies is a function that returns a pet
#note Wolfie cannot have babies, he's spayed

# %%
# so if I write

scar.has_babies()

# and i don't save the return value 
# this baby has been sent to the coding ether never to return

# %%
# you can also change attributes of your class
# let's name this kitty 

kitten.name ='Nala' 

kitten.get_name()
# Out:
# 'Nala'

# %%
# edit this cell to create your pet

your_pet = Pet('Chula')

# %%
# edit this cell to get its name using a function

your_pet.get_name()
# Out:
# 'Chula'

# %%
your_pet.name

# now get its name directly
# Out:
# 'Chula'

# %%
# edit this cell to make it say something
your_pet.speak('bark')
# Out:
# Chula says bark

# %%
# oops your pet had a baby 
# before running this cell, fix it so the baby does not end up in the coding ether

ChulasBaby = your_pet.has_babies()

# %%
# now spay your pet and its baby before you end up with 20,000 pets 

your_pet.get_spayed()

# %% [markdown]
# ## Accessing your data

# %%
#importing the toolbox that you are using
import pandas as pd
import xlrd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 #importing the toolbox that you are using
#       2 import pandas as pd
# ----> 3 import xlrd
#
# ModuleNotFoundError: No module named 'xlrd'

# %% [markdown]
# ### Paths

# %%
#starting the treasure hunt for your files
# !ls /datasets/labgmaildrive/Cum_SocialMemEphys/Phase3
# Out:
# 20230809_103121_1_merged.rec  20230810_140909_1_merged.rec
# 20230809_120416_1_merged.rec  20230811_101635_1_merged.rec
# 20230809_143303_1_merged.rec  20230811_120331_merged.rec
# 20230810_101534_1_merged.rec  20230811_154219_1_merged.rec
# 20230810_120856_1_merged.rec

# %%
#this is where you find out the name of the .xlsx
! ls /datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230810_101534_1_merged.rec
# Out:
# 20230810_101534_1.1_p3d2.xlsx  phy

# %% [markdown]
# # 140909

# %%
# !ls /datasets/labgmaildrive
# Out:
#  20230726_100544_1.1_1t1bL_A1.1.rec  'Contact List.xlsx'   open_me
# 'Colab Notebooks'		      Cum_SocialMemEphys

# %%
# when i tried to look up the .xlsx no file was there only show phy????
# open/read excel spread sheet
boris140909_df = pd.read_excel("/datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230810_101534_1_merged.rec/20230810_101534_1.1_p3d2.xlsx")

boris140909_df

# %% [markdown]
# # 101534

# %%
# open/read excel spread sheet
boris101534_df = pd.read_excel("/datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230810_101534_1_merged.rec/20230810_101534_1.1_p3d2.xlsx")

boris101534_df
# Out:
#     Observation id     Observation date  Description Observation type  \
# 0         1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# 1         1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# 2         1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# 3         1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# 4         1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# ..             ...                  ...          ...              ...
# 266       1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# 267       1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# 268       1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# 269       1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
# 270       1.1_p3d2  2023-08-25 10:56:56          NaN       Media file
#
#                                                 Source  Total duration  \
# ...

# %%
# create a specific dictionary for each 10 min chunnk FOR EACH RECORDING 

socialagent_second10min_dict = {'sniff cup 3': 'familiar','chew cup 3':'familiar'}
socialagent_third10min_dict = {'sniff cup 3': 'familiar','chew cup 3':'familiar'}
socialagent_dict = {'sniff cup 1': 'empty','chew cup 1':'empty','sniff cup 2': 'novel','chew cup 2':'novel','sniff cup 3': 'familiar','chew cup 3':'familiar','sniff cup 4': 'cagemate','chew cup 4':'cagemate'}
# this is where you are trimming down your columns to ONLy the ones you want
trimmed101534_df = boris101534_df[['Subject','Behavior','Start (s)','Stop (s)', 'Duration (s)']].copy()
# add a column called SocialAgent
trimmed101534_df['SocialAgent'] = trimmed101534_df['Behavior']


#now start chunking your df into four dfs based on Start (s) from the excel on teams
last10min101534_df = trimmed101534_df[trimmed101534_df['Start (s)'] > 1956]
first10min101534_df = trimmed101534_df[trimmed101534_df['Start (s)'] < 600]
second10min101534_df = trimmed101534_df[(trimmed101534_df['Start (s)'] < 1216) & (trimmed101534_df['Start (s)'] > 600)]
third10min101534_df = trimmed101534_df[(trimmed101534_df['Start (s)'] > 1216) & (trimmed101534_df['Start (s)'] < 1821)]


#use your dictionary to edit social agent column 
last10min101534_df = last10min101534_df.replace({'SocialAgent': socialagent_dict})
second10min101534_df = second10min101534_df.replace({'SocialAgent': socialagent_third10min_dict})
#third10min101534_df = third10min101534_df.replace({'SocialAgent': socialagent_third10min_dict})
#look at your df and make sure it makes sense
third10min101534_df
# Out:
#      Subject     Behavior  Start (s)  Stop (s)  Duration (s)  SocialAgent
# 132      1.1  sniff cup 1   1230.300  1231.000         0.700  sniff cup 1
# 133      1.1  sniff cup 4   1234.767  1235.533         0.766  sniff cup 4
# 134      1.1  sniff cup 4   1236.067  1237.667         1.600  sniff cup 4
# 135      1.1  sniff cup 2   1242.300  1244.533         2.233  sniff cup 2
# 136      1.1  sniff cup 4   1252.967  1257.033         4.066  sniff cup 4
# ..       ...          ...        ...       ...           ...          ...
# 198      1.1  sniff cup 2   1763.100  1764.367         1.267  sniff cup 2
# 199      1.1  sniff cup 2   1765.133  1771.233         6.100  sniff cup 2
# 200      1.1  sniff cup 2   1772.333  1775.100         2.767  sniff cup 2
# 201      1.1  sniff cup 1   1791.167  1791.833         0.666  sniff cup 1
# 202      1.1  sniff cup 3   1814.833  1820.767         5.934  sniff cup 3
#
# [71 rows x 6 columns]

# %% [markdown]
# # 120856

# %%
# when i tried to look up the .xlsx no file was there only show phy????
# open/read excel spread sheet
boris120856_df = pd.read_excel("/work/20230810_120856_1.2_p3d2.xlsx")

boris120856_df
# Out:
#     Observation id     Observation date  Description Observation type  \
# 0         1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# 1         1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# 2         1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# 3         1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# 4         1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# ..             ...                  ...          ...              ...
# 204       1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# 205       1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# 206       1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# 207       1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
# 208       1.2_p3d2  2023-08-25 11:37:21          NaN       Media file
#
#                                 Source  Total duration  Media duration (s)  \
# ...

# %%
# create a specific dictionary for each 10 min chunnk FOR EACH RECORDING 

socialagent_second10min_dict = {'sniff cup 3': 'familiar','chew cup 3':'familiar'}
socialagent_third10min_dict = {'sniff cup 3': 'familiar','chew cup 3':'familiar'}
socialagent_dict = {'sniff cup 1': 'empty','chew cup 1':'empty','sniff cup 2': 'novel','chew cup 2':'novel','sniff cup 3': 'familiar','chew cup 3':'familiar','sniff cup 4': 'cagemate','chew cup 4':'cagemate'}
# this is where you are trimming down your columns to ONLy the ones you want
trimmed12041612_df = boris12041612_df[['Subject','Behavior','Start (s)','Stop (s)', 'Duration (s)']].copy()
# add a column called SocialAgent
trimmed12041612_df['SocialAgent'] = trimmed12041612_df['Behavior']


#now start chunking your df into four dfs based on Start (s) from the excel on teams
last10min12041612_df = trimmed12041612_df[trimmed12041612_df['Start (s)'] > 1376]
first10min12041612_df = trimmed12041612_df[trimmed12041612_df['Start (s)'] < 30]
second10min12041612_df = trimmed12041612_df[(trimmed12041612_df['Start (s)'] < 646) & (trimmed12041612_df['Start (s)'] > 30)]
third10min12041612_df = trimmed12041612_df[(trimmed12041612_df['Start (s)'] > 646) & (trimmed12041612_df['Start (s)'] < 1263)]


#use your dictionary to edit social agent column 
last10min12041612_df = last10min12041612_df.replace({'SocialAgent': socialagent_dict})
second10min12041612_df = second10min12041612_df.replace({'SocialAgent': socialagent_third10min_dict})
#third10min12041612_df = third10min12041612_df.replace({'SocialAgent': socialagent_third10min_dict})
#look at your df and make sure it makes sense
third10min12041612_df

# %% [markdown]
# # 1203311

# %%
# when i tried to look up the .xlsx no file was there only show phy????
# open/read excel spread sheet
boris1203311_df = pd.read_excel("ls /datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230811_120331_merged.rec/")

boris1203311_df

# %% [markdown]
# # 1203312

# %%
# when i tried to look up the .xlsx no file was there only show phy????
# open/read excel spread sheet
boris1203312_df = pd.read_excel("ls /datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230811_120331_merged.rec/")

boris1203312_df

# %% [markdown]
# # 12041612

# %%
# open/read excel spread sheet
boris12041612_df = pd.read_excel("/datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230809_120416_1_merged.rec/20230809 120416 1.2.xlsx")

boris12041612_df
# Out:
#          Observation id     Observation date  Description Observation type  \
# 0   20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# 1   20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# 2   20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# 3   20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# 4   20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# ..                  ...                  ...          ...              ...
# 84  20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# 85  20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# 86  20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# 87  20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
# 88  20230809 120416 1.2  2023-09-08 16:39:21          NaN       Media file
#
# ...

# %%
# create a specific dictionary for each 10 min chunnk FOR EACH RECORDING 

socialagent_second10min_dict = {'sniff cup 3': 'familiar','chew cup 3':'familiar'}
socialagent_third10min_dict = {'sniff cup 3': 'familiar','chew cup 3':'familiar'}
socialagent_dict = {'sniff cup 1': 'empty','chew cup 1':'empty','sniff cup 2': 'novel','chew cup 2':'novel','sniff cup 3': 'familiar','chew cup 3':'familiar','sniff cup 4': 'cagemate','chew cup 4':'cagemate'}
# this is where you are trimming down your columns to ONLy the ones you want
trimmed12041612_df = boris12041612_df[['Subject','Behavior','Start (s)','Stop (s)', 'Duration (s)']].copy()
# add a column called SocialAgent
trimmed12041612_df['SocialAgent'] = trimmed12041612_df['Behavior']


#now start chunking your df into four dfs based on Start (s) from the excel on teams
last10min12041612_df = trimmed12041612_df[trimmed12041612_df['Start (s)'] > 1376]
first10min12041612_df = trimmed12041612_df[trimmed12041612_df['Start (s)'] < 30]
second10min12041612_df = trimmed12041612_df[(trimmed12041612_df['Start (s)'] < 646) & (trimmed12041612_df['Start (s)'] > 30)]
third10min12041612_df = trimmed12041612_df[(trimmed12041612_df['Start (s)'] > 646) & (trimmed12041612_df['Start (s)'] < 1263)]


#use your dictionary to edit social agent column 
last10min12041612_df = last10min12041612_df.replace({'SocialAgent': socialagent_dict})
second10min12041612_df = second10min12041612_df.replace({'SocialAgent': socialagent_third10min_dict})
#third10min12041612_df = third10min12041612_df.replace({'SocialAgent': socialagent_third10min_dict})
#look at your df and make sure it makes sense
third10min12041612_df
# Out:
#     Subject     Behavior  Start (s)  Stop (s)  Duration (s)  SocialAgent
# 36      1.2  sniff cup 3    690.667   691.567         0.900  sniff cup 3
# 37      1.2  sniff cup 3    706.600   708.800         2.200  sniff cup 3
# 38      1.2  sniff cup 3    727.633   731.200         3.567  sniff cup 3
# 39      1.2  sniff cup 2    769.900   771.167         1.267  sniff cup 2
# 40      1.2   chew cup 4    801.600   807.032         5.432   chew cup 4
# 41      1.2  sniff cup 4    807.033   825.433        18.400  sniff cup 4
# 42      1.2  sniff cup 4    868.167   872.167         4.000  sniff cup 4
# 43      1.2  sniff cup 2   1030.100  1031.133         1.033  sniff cup 2
# 44      1.2  sniff cup 4   1049.433  1055.766         6.333  sniff cup 4
# 45      1.2   chew cup 4   1055.767  1070.933        15.166   chew cup 4
# 46      1.2  sniff cup 4   1071.800  1085.467        13.667  sniff cup 4
# 47      1.2   chew cup 4   1089.933  1100.733        10.800   chew cup 4
# ...

# %% [markdown]
# # 101635

# %%
# open/read excel spread sheet
boris101635_df = pd.read_excel("/datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230811_101635_1_merged.rec/1.1_p3d3.xlsx")

boris101635_df
# Out:
#     Observation id     Observation date  Description Observation type  \
# 0         1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# 1         1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# 2         1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# 3         1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# 4         1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# ..             ...                  ...          ...              ...
# 231       1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# 232       1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# 233       1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# 234       1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
# 235       1.1_p3p3  2023-09-10 08:51:06          NaN       Media file
#
#                                 Source  Total duration  Media duration (s)  \
# ...

# %%
# create a specific dictionary for each 10 min chunnk FOR EACH RECORDING 

socialagent_second10min_dict = {'sniff cup 4': 'familiar','chew cup 4':'familiar'}
socialagent_third10min_dict = {'sniff cup 4': 'familiar','chew cup 4':'familiar'}
socialagent_dict = {'sniff cup 1': 'cagemate','chew cup 1':'cagemate','sniff cup 2': 'empty','chew cup 2':'empty','sniff cup 3': 'novel','chew cup 3':'novel','sniff cup 4': 'familiar','chew cup 4':'familiar'}
# this is where you are trimming down your columns to ONLy the ones you want
trimmed101635_df = boris101635_df[['Subject','Behavior','Start (s)','Stop (s)', 'Duration (s)']].copy()
# add a column called SocialAgent
trimmed101635_df['SocialAgent'] = trimmed101635_df['Behavior']


#now start chunking your df into four dfs based on Start (s) from the excel on teams
last10min101635_df = trimmed101635_df[trimmed101635_df['Start (s)'] > 1903]
first10min101635_df = trimmed101635_df[trimmed101635_df['Start (s)'] < 601]
second10min101635_df = trimmed101635_df[(trimmed101635_df['Start (s)'] < 1208) & (trimmed101635_df['Start (s)'] > 601)]
third10min101635_df = trimmed101635_df[(trimmed101635_df['Start (s)'] > 1208) & (trimmed101635_df['Start (s)'] < 1809)]


#use your dictionary to edit social agent column 
last10min101635_df = last10min101635_df.replace({'SocialAgent': socialagent_dict})
second10min101635_df = second10min101635_df.replace({'SocialAgent': socialagent_third10min_dict})
#third10min101635_df = third10min101635_df.replace({'SocialAgent': socialagent_third10min_dict})
#look at your df and make sure it makes sense
last10min101635_df
# Out:
#      Subject     Behavior  Start (s)  Stop (s)  Duration (s) SocialAgent
# 182      1.1  sniff cup 4   1907.200  1933.900        26.700    familiar
# 183      1.1  sniff cup 4   1941.700  1950.433         8.733    familiar
# 184      1.1  sniff cup 1   1954.700  1974.733        20.033    cagemate
# 185      1.1  sniff cup 3   1977.367  1977.733         0.366       novel
# 186      1.1  sniff cup 3   1979.500  1990.900        11.400       novel
# 187      1.1  sniff cup 1   2036.233  2038.000         1.767    cagemate
# 188      1.1  sniff cup 1   2039.433  2044.667         5.234    cagemate
# 189      1.1  sniff cup 4   2051.533  2057.633         6.100    familiar
# 190      1.1  sniff cup 1   2067.467  2087.967        20.500    cagemate
# 191      1.1  sniff cup 4   2091.767  2101.167         9.400    familiar
# 192      1.1  sniff cup 1   2114.167  2114.567         0.400    cagemate
# 193      1.1  sniff cup 2   2116.167  2124.733         8.566       empty
# ...

# %% [markdown]
# # 12041611

# %%
# open/read excel spread sheet
boris12041611_df = pd.read_excel("/datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230809_120416_1_merged.rec/20230809 120416 1.1.xlsx")

boris12041611_df
# Out:
#          Observation id     Observation date  Description Observation type  \
# 0   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 1   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 2   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 3   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 4   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 5   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 6   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 7   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 8   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 9   20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# 10  20230809 120416 1.1  2023-09-08 16:20:04          NaN       Media file
# ...

# %%
# create a specific dictionary for each 10 min chunnk FOR EACH RECORDING 
# did not create dictionary for recording 12041611 
trimmed12041611_df = boris12041611_df[['Subject','Behavior','Start (s)','Stop (s)', 'Duration (s)']].copy()

# add a column called SocialAgent
trimmed12041611_df['SocialAgent'] = trimmed12041611_df['Behavior']


#now start chunking your df into four dfs based on Start (s) from the excel on teams
# did not need to chunck time as there are only first10min in the recording
first10min12041611_df = trimmed12041611_df[trimmed12041611_df['Start (s)'] < 523]


#use your dictionary to edit social agent column 
last10min12041611_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 4
#       1 _deepnote_current_table_attrs = '{"pageSize":10,"pageIndex":0,"sortBy":[],"filters":[]}'
#       2 # create a specific dictionary for each 10 min chunnk FOR EACH RECORDING
#       3 # did not create dictionary for recording 12041611
# ----> 4 trimmed12041611_df = boris12041611_df[['Subject','Behavior','Start (s)','Stop (s)', 'Duration (s)']].copy()
#       6 # add a column called SocialAgent
#       7 trimmed12041611_df['SocialAgent'] = trimmed12041611_df['Behavior']
#
# NameError: name 'boris12041611_df' is not defined

# %% [markdown]
# ## 103121

# %%
# open/read excel spread sheet
boris_df = pd.read_excel("/datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230809_103121_1_merged.rec/20230809_103121_1.1_1t1bL_p3d1.xlsx")

boris_df
# Out:
#                      Observation id     Observation date  Description  \
# 0    20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# 1    20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# 2    20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# 3    20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# 4    20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# ..                              ...                  ...          ...
# 135  20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# 136  20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# 137  20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# 138  20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
# 139  20230809_103121_1.1_1t1bL_p3d1  2023-09-08 11:37:22          NaN
#
#     Observation type                                             Source  \
# ...

# %% [markdown]
# # 103121

# %%
# create a specific dictionary for each 10 min chunnk FOR EACH RECORDING 

socialagent_second10min_dict = {'sniff cup 2': 'familiar','chew cup 2':'familiar'}
socialagent_third10min_dict = {'sniff cup 2': 'familiar','chew cup 2':'familiar'}
socialagent_dict = {'sniff cup 1': 'novel','chew cup 1':'novel','sniff cup 2': 'familiar','chew cup 2':'familiar','sniff cup 3': 'cagemate','chew cup 3':'cagemate','sniff cup 4': 'empty','chew cup 4':'empty'}
# this is where you are trimming down your columns to ONLy the ones you want
trimmed_df = boris_df[['Subject','Behavior','Start (s)','Stop (s)', 'Duration (s)']].copy()
# add a column called SocialAgent
trimmed_df['SocialAgent'] = trimmed_df['Behavior']


#now start chunking your df into four dfs based on Start (s) from the excel on teams
last10min_df = trimmed_df[trimmed_df['Start (s)'] > 1939]
first10min_df = trimmed_df[trimmed_df['Start (s)'] < 601]
second10min_df = trimmed_df[(trimmed_df['Start (s)'] < 1258) & (trimmed_df['Start (s)'] > 601)]
third10min_df = trimmed_df[(trimmed_df['Start (s)'] > 1258) & (trimmed_df['Start (s)'] < 1860)]


#use your dictionary to edit social agent column 
last10min_df = last10min_df.replace({'SocialAgent': socialagent_dict})
second10min_df = second10min_df.replace({'SocialAgent': socialagent_third10min_dict})
#third10min_df = third10min_df.replace({'SocialAgent': socialagent_third10min_dict})
#look at your df and make sure it makes sense
third10min_df
# Out:
#      Subject     Behavior  Start (s)  Stop (s)  Duration (s)  SocialAgent
# 70       1.1  sniff cup 1   1274.733  1275.933         1.200  sniff cup 1
# 71       1.1  sniff cup 1   1368.333  1369.967         1.634  sniff cup 1
# 72       1.1  sniff cup 1   1382.567  1383.500         0.933  sniff cup 1
# 73       1.1  sniff cup 1   1385.333  1389.900         4.567  sniff cup 1
# 74       1.1  sniff cup 2   1394.467  1399.233         4.766  sniff cup 2
# 75       1.1  sniff cup 3   1403.367  1410.767         7.400  sniff cup 3
# 76       1.1  sniff cup 2   1418.533  1423.133         4.600  sniff cup 2
# 77       1.1  sniff cup 1   1435.267  1444.000         8.733  sniff cup 1
# 78       1.1   chew cup 1   1446.267  1448.832         2.565   chew cup 1
# 79       1.1  sniff cup 1   1448.833  1452.467         3.634  sniff cup 1
# 80       1.1   chew cup 1   1455.167  1460.400         5.233   chew cup 1
# 81       1.1   chew cup 1   1463.133  1464.400         1.267   chew cup 1
# ...

# %% [markdown]
# # 143303

# %%
# open/read excel spread sheet
boris143303_df = pd.read_excel("/datasets/labgmaildrive/Cum_SocialMemEphys/Phase3/20230809_143303_1_merged.rec/20230809_143303_1.4_3t3bL_p3d1.xlsx")

boris143303_df
# Out:
#     Observation id     Observation date  Description Observation type  \
# 0         1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# 1         1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# 2         1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# 3         1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# 4         1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# ..             ...                  ...          ...              ...
# 253       1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# 254       1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# 255       1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# 256       1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
# 257       1.4_p3d1  2023-09-13 08:59:08          NaN       Media file
#
#                                                 Source  Total duration  \
# ...

# %%
# create a specific dictionary for each 10 min chunnk FOR EACH RECORDING 

socialagent_second10min_dict = {'sniff cup 2': 'familiar','chew cup 2':'familiar'}
socialagent_third10min_dict = {'sniff cup 2': 'familiar','chew cup 2':'familiar'}
socialagent_dict = {'sniff cup 1': 'cagemate','chew cup 1':'cagemate','sniff cup 2': 'familiar','chew cup 2':'familiar','sniff cup 3': 'novel','chew cup 3':'novel','sniff cup 4': 'empty','chew cup 4':'empty'}
# this is where you are trimming down your columns to ONLy the ones you want
trimmed143303_df = boris143303_df[['Subject','Behavior','Start (s)','Stop (s)', 'Duration (s)']].copy()

# add a column called SocialAgent
trimmed143303_df['SocialAgent'] = trimmed143303_df['Behavior']


#now start chunking your df into four dfs based on Start (s) from the excel on teams
last10min143303_df = trimmed143303_df[trimmed143303_df['Start (s)'] > 1959]
first10min143303_df = trimmed143303_df[trimmed143303_df['Start (s)'] < 602]
second10min143303_df = trimmed143303_df[(trimmed143303_df['Start (s)'] < 1234) & (trimmed143303_df['Start (s)'] > 602)]
third10min143303_df = trimmed143303_df[(trimmed143303_df['Start (s)'] > 1234) & (trimmed143303_df['Start (s)'] < 1856)]


#use your dictionary to edit social agent column 
last10min143303_df = last10min143303_df.replace({'SocialAgent': socialagent_dict})
second10min143303_df = second10min143303_df.replace({'SocialAgent': socialagent_third10min_dict})
#third10min143303_df = third10min143303_df.replace({'SocialAgent': socialagent_third10min_dict})
#look at your df and make sure it makes sense
last10min143303_df
# Out:
#      Subject     Behavior  Start (s)  Stop (s)  Duration (s) SocialAgent
# 189      1.4  sniff cup 2   1960.467  1961.367         0.900    familiar
# 190      1.4  sniff cup 4   1964.000  1964.300         0.300       empty
# 191      1.4  sniff cup 4   1964.700  1964.900         0.200       empty
# 192      1.4  sniff cup 2   1968.067  1971.500         3.433    familiar
# 193      1.4  sniff cup 2   1972.000  1972.567         0.567    familiar
# ..       ...          ...        ...       ...           ...         ...
# 253      1.4  sniff cup 2   2530.800  2535.233         4.433    familiar
# 254      1.4  sniff cup 3   2540.600  2541.300         0.700       novel
# 255      1.4  sniff cup 3   2544.500  2544.867         0.367       novel
# 256      1.4  sniff cup 2   2550.233  2550.900         0.667    familiar
# 257      1.4  sniff cup 2   2551.433  2552.833         1.400    familiar
#
# [69 rows x 6 columns]

# %%
last10min_master_df = pd.concat([last10min_df, last10min143303_df], axis = 0)
first10min_master_df = pd.concat([first10min_df, first10min143303_df], axis = 0)
second10min_master_df = pd.concat([second10min_df, second10min143303_df], axis = 0)
third10min_master_df = pd.concat([third10min_df, third10min143303_df], axis = 0)

# %%
last10min_master_df = pd.concat([last10min_master_df, last10min101635_df], axis = 0)
first10min_master_df = pd.concat([first10min_master_df, first10min101635_df], axis = 0)
second10min_master_df = pd.concat([second10min_master_df, second10min101635_df], axis = 0)
third10min_master_df = pd.concat([third10min_master_df, third10min101635_df], axis = 0)

# %%
first10min_master_df = pd.concat([first10min_master_df,first10min12041611_df], axis = 0)

# %%
last10min_master_df = pd.concat([last10min_master_df, last10min12041612_df], axis = 0)
first10min_master_df = pd.concat([first10min_master_df, first10min12041612_df], axis = 0)
second10min_master_df = pd.concat([second10min_master_df, second10min12041612_df], axis = 0)
third10min_master_df = pd.concat([third10min_master_df, third10min12041612_df], axis = 0)

# %%
last10min_master_df = pd.concat([last10min_master_df, last10min101534_df], axis = 0)
first10min_master_df = pd.concat([first10min_master_df, first10min101534_df], axis = 0)
second10min_master_df = pd.concat([second10min_master_df, second10min101534_df], axis = 0)
third10min_master_df = pd.concat([third10min_master_df, third10min101534_df], axis = 0)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5af4ec4f-bb5a-44fc-b66c-61573cb96cdd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
